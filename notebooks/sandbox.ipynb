# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black

# %%
from datasets import load_dataset

MM = load_dataset(
    "bigbio/medmentions", name="medmentions_st21pv_bigbio_kb", trust_remote_code=True
)
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
from longbel.parse_data_long import parse_text
import nltk

start_entity = "["
end_entity = "]"
start_group = "{"
end_group = "}"
nlp = nltk.data.load("tokenizers/punkt/english.pickle")
# Out:
# ['Nonylphenol diethoxylate inhibits [apoptosis]{GROUP} induced in PC12 cells',
#  'Nonylphenol diethoxylate inhibits apoptosis induced in [PC12 cells]{GROUP}',
#  'Nonylphenol and short-chain nonylphenol ethoxylates such as NP2 EO are [present]{GROUP} in aquatic environment as wastewater contaminants, and their toxic effects on aquatic species have been reported.',
#  'Nonylphenol and short-chain nonylphenol ethoxylates such as NP2 EO are present in aquatic environment as wastewater contaminants, and their [toxic effects]{GROUP} on aquatic species have been reported.',
#  '[Apoptosis]{GROUP} has been shown to be induced by serum deprivation or copper treatment.',
#  'Apoptosis has been shown to be induced by [serum]{GROUP} deprivation or copper treatment.',
#  'Apoptosis has been shown to be induced by serum deprivation or [copper]{GROUP} treatment.',
# ...

# %%
parse_text(MM["test"][0], start_entity, end_entity, start_group, end_group, nlp=nlp)
# Out:
# ['Nonylphenol diethoxylate inhibits [apoptosis]{GROUP} induced in [PC12 cells]{GROUP}',
# ...

# %%
MM["test"][0]
# Out:
# {'id': '0',
#  'document_id': '25847295',
#  'passages': [{'id': '34',
#    'type': 'title',
#    'text': ['Nonylphenol diethoxylate inhibits apoptosis induced in PC12 cells'],
#    'offsets': [[0, 65]]},
#   {'id': '35',
#    'type': 'abstract',
# ...
